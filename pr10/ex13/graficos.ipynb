# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('res_insR_quaseordenado.csv', skiprows=[1]) #, nrows=1998)
#df['n'] = pd.to_numeric(df['n'], errors='coerce')
#df['tempo'] = pd.to_numeric(df['tempo'], errors='coerce')

# %%
df['n'] = pd.to_numeric(df['n'])
df['tempo'] = pd.to_numeric(df['tempo'])

# %%
df.plot(x = 'n', y= 'tempo')
plt.ylabel("Tempo (s)")
plt.ylabel("n")
plt.title(f"Selection Sort")
# Out:
# Text(0.5, 1.0, 'Selection Sort')

# %%
arquivos = ['100000-contrario.txt', '100000-misturado.txt',
            '100000-ordenado.txt', '100000-quaseordenado.txt']
condicao = ['contrario', 'misturado', 'ordenado', 'quaseordenado']
algoritmos = [1, 12, 2, 21, 3, 32]
nomeAlgoritmo = ['ins', 'insR', 'selec', 'selecR', 'bubble', 'bubbleR']

fig, axs = plt.subplots(4, 6)

for i, arquivo in enumerate(arquivos):
    for j, algoritmo in enumerate(algoritmos):
        nome_saida = f"res_"+nomeAlgoritmo[j]+"_"+condicao[i]+".csv"
        
        df = pd.read_csv(nome_saida, skiprows=[1])

        df['n'] = pd.to_numeric(df['n'])
        df['tempo'] = pd.to_numeric(df['tempo'])

        axs[i][j].plot(x = 'n', y= 'tempo')
        axs[i][j].ylabel("Tempo (s)")
        axs[i][j].ylabel("n")
        axs[i][j].title(f"{algoritmo} {condicao[i]}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/zonzin/Documentos/Faculdade/labaedsii/labaeds2/pr10/ex13/graficos.ipynb Célula 5 line 1
#      <a href='vscode-notebook-cell:/home/zonzin/Documentos/Faculdade/labaedsii/labaeds2/pr10/ex13/graficos.ipynb#W1sZmlsZQ%3D%3D?line=14'>15</a> df['n'] = pd.to_numeric(df['n'])
#      <a href='vscode-notebook-cell:/home/zonzin/Documentos/Faculdade/labaedsii/labaeds2/pr10/ex13/graficos.ipynb#W1sZmlsZQ%3D%3D?line=15'>16</a> df['tempo'] = pd.to_numeric(df['tempo'])
# ---> <a href='vscode-notebook-cell:/home/zonzin/Documentos/Faculdade/labaedsii/labaeds2/pr10/ex13/graficos.ipynb#W1sZmlsZQ%3D%3D?line=17'>18</a> axs[i][j].plot(x = 'n', y= 'tempo')
#      <a href='vscode-notebook-cell:/home/zonzin/Documentos/Faculdade/labaedsii/labaeds2/pr10/ex13/graficos.ipynb#W1sZmlsZQ%3D%3D?line=18'>19</a> axs[i][j].ylabel("Tempo (s)")
#      <a href='vscode-notebook-cell:/home/zonzin/Documentos/Faculdade/labaedsii/labaeds2/pr10/ex13/graficos.ipynb#W1sZmlsZQ%3D%3D?line=19'>20</a> axs[i][j].ylabel("n")
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
#    1634     self.add_line(line)
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:247, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     245 for pos_only in "xy":
#     246     if pos_only in kwargs:
# --> 247         raise TypeError("{} got an unexpected keyword argument {!r}"
#     248                         .format(self.command, pos_only))
#     250 if not args:
#     251     return
#
# TypeError: plot got an unexpected keyword argument 'x'

# %%
for i, ax in enumerate(axs.flatten):
    
    ax.plot(x = 'n', y= 'tempo')
    ax.ylabel("Tempo (s)")
    ax.ylabel("n")
    ax.title(f"Selection Sort")

# %%
# Definir a função que você quer plotar
def minha_funcao(x):
    f = lambda x:  8.830528e-8*x**2
    return (f(x))  # Por exemplo, a função seno

# Gerar valores de x
x_values = np.linspace(0, 10000, 30)  # Valores de -2π a 2π

# Calcular os valores da função para cada valor de x
y_values = minha_funcao(x_values)
for ivalue in y_values:
    y

# Plotar a função
plt.figure(figsize=(8, 6))  # Tamanho do gráfico
plt.plot(x_values, y_values, label='sin(x)', color='blue')  # Plotar a função
plt.title('Gráfico da Função Seno')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.legend()  # Mostrar legenda
plt.grid(True)  # Adicionar grade ao gráfico
plt.ylim(0, 7.5)
plt.show()
